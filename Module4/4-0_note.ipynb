# %%
# Markdown語法
# 兩邊冒號:置中,左右一邊冒號:置左/置右

# %% [markdown]
# |型態| 創建方式 | 可不可變 | 有序/無序 |
# |:---:|:---:|:---:|:---:|
# |list|ids = [1, 2, 3] |v |v |
# |dict|info = {"apple": 100, "orange": 50} | v| v|
# |tuple|ids = (1, 2, 3) |x |v |
# |set|ids = {1, 2, 3} |v |x |
# |string|name = "Leo" |x|v |
